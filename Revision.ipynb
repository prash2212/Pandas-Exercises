# %%
pwd
# Out:
# '/Users/prash/Google Drive/iMac/Machine Learning/Python/Pandas'

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame([[1,2],
                [3,4]],columns=['a','b'],index=['row1','row2'])
df1
# Out:
#       a  b
# row1  1  2
# row2  3  4

# %%
 df1.iloc[1]
# Out:
# a    3
# b    4
# Name: row2, dtype: int64

# %%
del df1.iloc[1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-7dfa603b3561> in <module>()
# ----> 1 del df1.iloc[1]
#
# AttributeError: __delitem__

# %%
pwd
# Out:
# '/Users/prash/Google Drive/iMac/Machine Learning/Python/Pandas'

# %%
ls
# Out:
# DataFrameFeeler.ipynb  TidyingUpData.ipynb    dailypricehistory.csv
# PlayingWithData.ipynb  Untitled.ipynb
# Revision.ipynb         Untitled1.ipynb

# %%
ls -ltr ../../Data/WM-sample.csv
# Out:
# -rw-------  1 prash  staff  597309 Jan  9 15:13 ../../Data/WM-sample.csv

# %%
head -t ""../../Data/WM-sample.csv""
# Out:
#   File "<ipython-input-34-b33a5e832918>", line 1
#     head -t ""../../Data/WM-sample.csv""
#              ^
# SyntaxError: invalid syntax

# %%
ls
# Out:
# DataFrameFeeler.ipynb  TidyingUpData.ipynb    dailypricehistory.csv
# PlayingWithData.ipynb  Untitled.ipynb
# Revision.ipynb         Untitled1.ipynb

# %%
head Revision.ipynb
# Out:
#   File "<ipython-input-37-1295aa6aca2e>", line 1
#     head Revision.ipynb
#                 ^
# SyntaxError: invalid syntax

# %%
dfcsv = pd.read_csv('../../Data/WM-sample.csv',index_col=['#RIC','Date[G]'])
dfcsv
# Out:
#                             Current RIC  Time[G]  GMT Offset            Type  \
# #RIC             Date[G]
# USDKRW1MNDFMP=WM 4-Jan-10           NaN  00:00.0           0  Intraday 1Hour
#                  5-Jan-10           NaN  00:00.0           0  Intraday 1Hour
#                  6-Jan-10           NaN  00:00.0           0  Intraday 1Hour
#                  7-Jan-10           NaN  00:00.0           0  Intraday 1Hour
#                  8-Jan-10           NaN  00:00.0           0  Intraday 1Hour
#                  9-Jan-10           NaN  00:00.0           0  Intraday 1Hour
#                  10-Jan-10          NaN  00:00.0           0  Intraday 1Hour
#                  11-Jan-10          NaN  00:00.0           0  Intraday 1Hour
#                  12-Jan-10          NaN  00:00.0           0  Intraday 1Hour
#                  13-Jan-10          NaN  00:00.0           0  Intraday 1Hour
#                  14-Jan-10          NaN  00:00.0           0  Intraday 1Hour
# ...

# %%
dfcsv['Current RIC']
#dfcsv.Open == np.NaN
# Out:
# #RIC              Date[G]
# USDKRW1MNDFMP=WM  4-Jan-10    NaN
#                   5-Jan-10    NaN
#                   6-Jan-10    NaN
#                   7-Jan-10    NaN
#                   8-Jan-10    NaN
#                   9-Jan-10    NaN
#                   10-Jan-10   NaN
#                   11-Jan-10   NaN
#                   12-Jan-10   NaN
#                   13-Jan-10   NaN
#                   14-Jan-10   NaN
#                   15-Jan-10   NaN
#                   16-Jan-10   NaN
#                   17-Jan-10   NaN
#                   18-Jan-10   NaN
#                   19-Jan-10   NaN
#                   20-Jan-10   NaN
#                   21-Jan-10   NaN
#                   22-Jan-10   NaN
#                   23-Jan-10   NaN
#                   24-Jan-10   NaN
#                   25-Jan-10   NaN
#                   26-Jan-10   NaN
#                   27-Jan-10   NaN
#                   28-Jan-10   NaN
#                   29-Jan-10   NaN
#                   30-Jan-10   NaN
# ...

# %%
nonNan= dfcsv[dfcsv.Open != np.NaN]
nonNan
# Out:
#                             Current RIC  Time[G]  GMT Offset            Type  \
# #RIC             Date[G]
# USDKRW1MNDFMP=WM 4-Jan-10           NaN  00:00.0           0  Intraday 1Hour
#                  5-Jan-10           NaN  00:00.0           0  Intraday 1Hour
#                  6-Jan-10           NaN  00:00.0           0  Intraday 1Hour
#                  7-Jan-10           NaN  00:00.0           0  Intraday 1Hour
#                  8-Jan-10           NaN  00:00.0           0  Intraday 1Hour
#                  9-Jan-10           NaN  00:00.0           0  Intraday 1Hour
#                  10-Jan-10          NaN  00:00.0           0  Intraday 1Hour
#                  11-Jan-10          NaN  00:00.0           0  Intraday 1Hour
#                  12-Jan-10          NaN  00:00.0           0  Intraday 1Hour
#                  13-Jan-10          NaN  00:00.0           0  Intraday 1Hour
#                  14-Jan-10          NaN  00:00.0           0  Intraday 1Hour
# ...

# %%
dfcsv
# Out:
# Empty DataFrame
# Columns: [index, #RIC, Date[G], Current RIC, Time[G], GMT Offset, Type, Open, High, Low, Last, Volume, Ave. Price, VWAP, No. Trades, Open Bid, High Bid, Low Bid, Close Bid, No. Bids, Open Ask, High Ask, Low Ask, Close Ask, No. Asks]
# Index: []
#
# [0 rows x 25 columns]

# %%
dfcsv
subset = dfcsv[:4]
subset
# Out:
#                            Current RIC  Time[G]  GMT Offset            Type  \
# #RIC             Date[G]
# USDKRW1MNDFMP=WM 4-Jan-10          NaN  00:00.0           0  Intraday 1Hour
#                  5-Jan-10          NaN  00:00.0           0  Intraday 1Hour
#                  6-Jan-10          NaN  00:00.0           0  Intraday 1Hour
#                  7-Jan-10          NaN  00:00.0           0  Intraday 1Hour
#
#                            Open  High  Low  Last  Volume  Ave. Price  \
# #RIC             Date[G]
# USDKRW1MNDFMP=WM 4-Jan-10   NaN   NaN  NaN   NaN     NaN         NaN
#                  5-Jan-10   NaN   NaN  NaN   NaN     NaN         NaN
#                  6-Jan-10   NaN   NaN  NaN   NaN     NaN         NaN
#                  7-Jan-10   NaN   NaN  NaN   NaN     NaN         NaN
#
#                              ...     Open Bid  High Bid  Low Bid  Close Bid  \
# #RIC             Date[G]     ...
# ...

# %%
dfcsv.reset_index(inplace=True)
subset = dfcsv[:4].copy()
subset
# Out:
#                #RIC   Date[G]  Current RIC  Time[G]  GMT Offset  \
# 0  USDKRW1MNDFMP=WM  4-Jan-10          NaN  00:00.0           0
# 1  USDKRW1MNDFMP=WM  5-Jan-10          NaN  00:00.0           0
# 2  USDKRW1MNDFMP=WM  6-Jan-10          NaN  00:00.0           0
# 3  USDKRW1MNDFMP=WM  7-Jan-10          NaN  00:00.0           0
#
#              Type  Open  High  Low  Last    ...     Open Bid  High Bid  \
# 0  Intraday 1Hour   NaN   NaN  NaN   NaN    ...      1156.90   1156.90
# 1  Intraday 1Hour   NaN   NaN  NaN   NaN    ...      1143.45   1143.45
# 2  Intraday 1Hour   NaN   NaN  NaN   NaN    ...      1137.10   1137.10
# 3  Intraday 1Hour   NaN   NaN  NaN   NaN    ...      1134.50   1134.50
#
#    Low Bid  Close Bid  No. Bids  Open Ask  High Ask  Low Ask  Close Ask  \
# 0  1156.90    1156.90         0       NaN       NaN      NaN        NaN
# 1  1143.45    1143.45         0       NaN       NaN      NaN        NaN
# ...

# %%
dfcsv
# Out:
#                   #RIC    Date[G]  Current RIC  Time[G]  GMT Offset  \
# 0     USDKRW1MNDFMP=WM   4-Jan-10          NaN  00:00.0           0
# 1     USDKRW1MNDFMP=WM   5-Jan-10          NaN  00:00.0           0
# 2     USDKRW1MNDFMP=WM   6-Jan-10          NaN  00:00.0           0
# 3     USDKRW1MNDFMP=WM   7-Jan-10          NaN  00:00.0           0
# 4     USDKRW1MNDFMP=WM   8-Jan-10          NaN  00:00.0           0
# 5     USDKRW1MNDFMP=WM   9-Jan-10          NaN  00:00.0           0
# 6     USDKRW1MNDFMP=WM  10-Jan-10          NaN  00:00.0           0
# 7     USDKRW1MNDFMP=WM  11-Jan-10          NaN  00:00.0           0
# 8     USDKRW1MNDFMP=WM  12-Jan-10          NaN  00:00.0           0
# 9     USDKRW1MNDFMP=WM  13-Jan-10          NaN  00:00.0           0
# 10    USDKRW1MNDFMP=WM  14-Jan-10          NaN  00:00.0           0
# 11    USDKRW1MNDFMP=WM  15-Jan-10          NaN  00:00.0           0
# 12    USDKRW1MNDFMP=WM  16-Jan-10          NaN  00:00.0           0
# ...

# %%
dfcsv.set_index(['#RIC','Date[G]'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/prash/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: '#RIC'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-92-df6e8bb0a397> in <module>()
# ...

# %%
dfcsv.xs('USDKRW1MNDFMP=WM')
# Out:
#            Current RIC  Time[G]  GMT Offset            Type     Open     High  \
# Date[G]
# 4-Jan-10           NaN  00:00.0           0  Intraday 1Hour      NaN      NaN
# 5-Jan-10           NaN  00:00.0           0  Intraday 1Hour      NaN      NaN
# 6-Jan-10           NaN  00:00.0           0  Intraday 1Hour      NaN      NaN
# 7-Jan-10           NaN  00:00.0           0  Intraday 1Hour      NaN      NaN
# 8-Jan-10           NaN  00:00.0           0  Intraday 1Hour      NaN      NaN
# 9-Jan-10           NaN  00:00.0           0  Intraday 1Hour      NaN      NaN
# 10-Jan-10          NaN  00:00.0           0  Intraday 1Hour      NaN      NaN
# 11-Jan-10          NaN  00:00.0           0  Intraday 1Hour      NaN      NaN
# 12-Jan-10          NaN  00:00.0           0  Intraday 1Hour      NaN      NaN
# 13-Jan-10          NaN  00:00.0           0  Intraday 1Hour      NaN      NaN
# 14-Jan-10          NaN  00:00.0           0  Intraday 1Hour      NaN      NaN
# ...

# %%
dfcsv.xs('4-Jan-10',level=1)
# Out:
#                   Current RIC  Time[G]  GMT Offset            Type    Open  \
# #RIC
# USDKRW1MNDFMP=WM          NaN  00:00.0           0  Intraday 1Hour     NaN
# USDKRWFIXMP=WM            NaN  00:00.0           0  Intraday 1Hour  1154.8
#
#                     High     Low    Last  Volume  Ave. Price    ...     \
# #RIC                                                            ...
# USDKRW1MNDFMP=WM     NaN     NaN     NaN     NaN         NaN    ...
# USDKRWFIXMP=WM    1154.8  1154.8  1154.8     0.0      1154.8    ...
#
#                   Open Bid  High Bid  Low Bid  Close Bid  No. Bids  Open Ask  \
# #RIC
# USDKRW1MNDFMP=WM    1156.9    1156.9   1156.9     1156.9         0       NaN
# USDKRWFIXMP=WM      1154.8    1154.8   1154.8     1154.8         1       NaN
#
#                   High Ask  Low Ask  Close Ask  No. Asks
# #RIC
# USDKRW1MNDFMP=WM       NaN      NaN        NaN         0
# USDKRWFIXMP=WM         NaN      NaN        NaN         0
#
# [2 rows x 22 columns]

# %%
dfcsv.describe()
# Out:
# /Users/prash/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        Current RIC  GMT Offset         Open         High          Low  \
# count          0.0      4894.0  3292.000000  3292.000000  3292.000000
# mean           NaN         0.0  1117.261554  1117.261554  1117.261554
# std            NaN         0.0    48.432621    48.432621    48.432621
# min            NaN         0.0  1008.350000  1008.350000  1008.350000
# 25%            NaN         0.0          NaN          NaN          NaN
# 50%            NaN         0.0          NaN          NaN          NaN
# 75%            NaN         0.0          NaN          NaN          NaN
# max            NaN         0.0  1254.100000  1254.100000  1254.100000
#
#               Last  Volume   Ave. Price  VWAP  No. Trades     Open Bid  \
# count  3292.000000  3292.0  3292.000000   0.0      3292.0  4894.000000
# ...

# %%
redcsv = pd.read_csv('../../Data/WM-sample.csv',header=0,usecols=['#RIC','Date[G]','Last','No. Trades'])
redcsv
# Out:
#                   #RIC    Date[G]     Last  No. Trades
# 0     USDKRW1MNDFMP=WM   4-Jan-10      NaN         NaN
# 1     USDKRW1MNDFMP=WM   5-Jan-10      NaN         NaN
# 2     USDKRW1MNDFMP=WM   6-Jan-10      NaN         NaN
# 3     USDKRW1MNDFMP=WM   7-Jan-10      NaN         NaN
# 4     USDKRW1MNDFMP=WM   8-Jan-10      NaN         NaN
# 5     USDKRW1MNDFMP=WM   9-Jan-10      NaN         NaN
# 6     USDKRW1MNDFMP=WM  10-Jan-10      NaN         NaN
# 7     USDKRW1MNDFMP=WM  11-Jan-10      NaN         NaN
# 8     USDKRW1MNDFMP=WM  12-Jan-10      NaN         NaN
# 9     USDKRW1MNDFMP=WM  13-Jan-10      NaN         NaN
# 10    USDKRW1MNDFMP=WM  14-Jan-10      NaN         NaN
# 11    USDKRW1MNDFMP=WM  15-Jan-10      NaN         NaN
# 12    USDKRW1MNDFMP=WM  16-Jan-10      NaN         NaN
# 13    USDKRW1MNDFMP=WM  17-Jan-10      NaN         NaN
# 14    USDKRW1MNDFMP=WM  18-Jan-10      NaN         NaN
# 15    USDKRW1MNDFMP=WM  19-Jan-10      NaN         NaN
# ...

# %%
redcsv[redcsv.Last.notnull() & redcsv['No. Trades'].notnull()]
# Out:
#                   #RIC    Date[G]     Last  No. Trades
# 84    USDKRW1MNDFMP=WM  29-Mar-10  1136.70         1.0
# 85    USDKRW1MNDFMP=WM  30-Mar-10  1131.45         1.0
# 86    USDKRW1MNDFMP=WM  31-Mar-10  1132.75         1.0
# 87    USDKRW1MNDFMP=WM   1-Apr-10  1127.65         1.0
# 91    USDKRW1MNDFMP=WM   5-Apr-10  1124.35         1.0
# 92    USDKRW1MNDFMP=WM   6-Apr-10  1124.20         1.0
# 93    USDKRW1MNDFMP=WM   7-Apr-10  1121.55         1.0
# 94    USDKRW1MNDFMP=WM   8-Apr-10  1124.55         1.0
# 95    USDKRW1MNDFMP=WM   9-Apr-10  1119.15         1.0
# 98    USDKRW1MNDFMP=WM  12-Apr-10  1115.10         1.0
# 99    USDKRW1MNDFMP=WM  13-Apr-10  1124.95         1.0
# 100   USDKRW1MNDFMP=WM  14-Apr-10  1113.75         1.0
# 101   USDKRW1MNDFMP=WM  15-Apr-10  1108.40         1.0
# 102   USDKRW1MNDFMP=WM  16-Apr-10  1111.00         1.0
# 105   USDKRW1MNDFMP=WM  19-Apr-10  1118.70         1.0
# 106   USDKRW1MNDFMP=WM  20-Apr-10  1118.75         1.0
# ...

# %%
redcsv.dropna(how='all')
# Out:
#                   #RIC    Date[G]     Last  No. Trades
# 0     USDKRW1MNDFMP=WM   4-Jan-10      NaN         NaN
# 1     USDKRW1MNDFMP=WM   5-Jan-10      NaN         NaN
# 2     USDKRW1MNDFMP=WM   6-Jan-10      NaN         NaN
# 3     USDKRW1MNDFMP=WM   7-Jan-10      NaN         NaN
# 4     USDKRW1MNDFMP=WM   8-Jan-10      NaN         NaN
# 5     USDKRW1MNDFMP=WM   9-Jan-10      NaN         NaN
# 6     USDKRW1MNDFMP=WM  10-Jan-10      NaN         NaN
# 7     USDKRW1MNDFMP=WM  11-Jan-10      NaN         NaN
# 8     USDKRW1MNDFMP=WM  12-Jan-10      NaN         NaN
# 9     USDKRW1MNDFMP=WM  13-Jan-10      NaN         NaN
# 10    USDKRW1MNDFMP=WM  14-Jan-10      NaN         NaN
# 11    USDKRW1MNDFMP=WM  15-Jan-10      NaN         NaN
# 12    USDKRW1MNDFMP=WM  16-Jan-10      NaN         NaN
# 13    USDKRW1MNDFMP=WM  17-Jan-10      NaN         NaN
# 14    USDKRW1MNDFMP=WM  18-Jan-10      NaN         NaN
# 15    USDKRW1MNDFMP=WM  19-Jan-10      NaN         NaN
# ...
